# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
train_data = pd.read_csv('./Data/train.csv').dropna()
test_data = pd.read_csv('./Data/test.csv')
train_data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
input_features = train_data[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch']].replace(['female', 'male'], [0,1])
output_features = train_data['Survived']

# %%
binary_feature_names = ['Sex']
numeric_feature_names = ['Pclass', 'Age', 'SibSp', 'Parch']
numeric_feature = input_features[numeric_feature_names]

# %% [markdown]
# # Input vector

# %%
inputs = {}

for name, column in input_features.items():
    if name in binary_feature_names:
        dtype = tf.int64
    elif input_features[name].dtype == object:
        dtype = tf.string
    else:
        dtype = tf.float32

    inputs[name] = tf.keras.Input(
      shape=(), name=name, dtype=dtype)

inputs
# Out:
# {'Pclass': <KerasTensor: shape=(None,) dtype=float32 (created by layer 'Pclass')>,
#  'Sex': <KerasTensor: shape=(None,) dtype=int64 (created by layer 'Sex')>,
#  'Age': <KerasTensor: shape=(None,) dtype=float32 (created by layer 'Age')>,
#  'SibSp': <KerasTensor: shape=(None,) dtype=float32 (created by layer 'SibSp')>,
#  'Parch': <KerasTensor: shape=(None,) dtype=float32 (created by layer 'Parch')>}

# %% [markdown]
# # Preprocessing
# Unpack each row as one data sample using tf.stack.
# Convert the list of tensor into a tensor with rank one higher than each tensor

# %%
def stack_dict(inputs, fun=tf.stack):
    values = []
    for key in sorted(inputs.keys()):
      values.append(tf.cast(inputs[key], tf.float32))

    return fun(values, axis=-1)

# %%
preprocessed = []
for feature_name in binary_feature_names:
    temp = inputs[feature_name]
    temp = tf.expand_dims(temp, axis=1)
    temp_float = tf.cast(temp, tf.float32)
    preprocessed.append(temp_float)

preprocessed
# Out:
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'tf.cast')>]

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(stack_dict(dict(numeric_feature)))

# %%
numeric_inputs = {}
for name in numeric_feature_names:
  numeric_inputs[name]=inputs[name]

numeric_inputs = stack_dict(numeric_inputs)
numeric_normalized = normalizer(numeric_inputs)

preprocessed.append(numeric_normalized)

preprocessed
# Out:
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'tf.cast')>,
#  <KerasTensor: shape=(None, 4) dtype=float32 (created by layer 'normalization')>]

# %%
preprocesssed_result = tf.concat(preprocessed, axis=-1)
preprocesssed_result
# Out:
# <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'tf.concat')>

# %%
preprocessor = tf.keras.Model(inputs, preprocesssed_result)

# %%
tf.keras.utils.plot_model(preprocessor, rankdir="LR", show_shapes=True)

# %%
preprocessor(dict(input_features.iloc[:1]))
# Out:
# <tf.Tensor: shape=(1, 5), dtype=float32, numpy=
# array([[ 0.        ,  0.14906502, -0.6317298 , -0.37225628,  0.8336275 ]],
#       dtype=float32)>

# %% [markdown]
# # Build Model

# %%
body = tf.keras.Sequential([
  tf.keras.layers.Dense(10, activation='relu'),
  tf.keras.layers.Dense(10, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
inputs
# Out:
# {'Pclass': <KerasTensor: shape=(None,) dtype=float32 (created by layer 'Pclass')>,
#  'Sex': <KerasTensor: shape=(None,) dtype=int64 (created by layer 'Sex')>,
#  'Age': <KerasTensor: shape=(None,) dtype=float32 (created by layer 'Age')>,
#  'SibSp': <KerasTensor: shape=(None,) dtype=float32 (created by layer 'SibSp')>,
#  'Parch': <KerasTensor: shape=(None,) dtype=float32 (created by layer 'Parch')>}

# %%
x = preprocessor(inputs)
x
# Out:
# <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'model')>

# %%
result = body(x)
result
# Out:
# <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'sequential')>

# %%
model = tf.keras.Model(inputs, result)

model.compile(optimizer='adam',
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Age (InputLayer)               [(None,)]            0           []
#
#  Parch (InputLayer)             [(None,)]            0           []
#
#  Pclass (InputLayer)            [(None,)]            0           []
#
#  Sex (InputLayer)               [(None,)]            0           []
#
#  SibSp (InputLayer)             [(None,)]            0           []
#
#  model (Functional)             (None, 5)            9           ['Age[0][0]',
#                                                                   'Parch[0][0]',
#                                                                   'Pclass[0][0]',
#                                                                   'Sex[0][0]',
#                                                                   'SibSp[0][0]']
#
#  sequential (Sequential)        (None, 1)            181         ['model[0][0]']
#
# ==================================================================================================
# Total params: 190
# Trainable params: 181
# Non-trainable params: 9
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, "my_first_model_with_shape_info.png", show_shapes=True)

# %%
ds = tf.data.Dataset.from_tensor_slices((
    dict(input_features),
    output_features
))
BATCH_SIZE=8
ds = ds.batch(BATCH_SIZE)

# %%
import pprint

for x, y in ds.take(1):
  pprint.pprint(x)
  print()
  print(y)
# Out:
# {'Age': <tf.Tensor: shape=(8,), dtype=float64, numpy=array([38., 35., 54.,  4., 58., 34., 28., 19.])>,
#  'Parch': <tf.Tensor: shape=(8,), dtype=int64, numpy=array([0, 0, 0, 1, 0, 0, 0, 2], dtype=int64)>,
#  'Pclass': <tf.Tensor: shape=(8,), dtype=int64, numpy=array([1, 1, 1, 3, 1, 2, 1, 1], dtype=int64)>,
#  'Sex': <tf.Tensor: shape=(8,), dtype=int64, numpy=array([0, 0, 1, 0, 0, 1, 1, 1], dtype=int64)>,
#  'SibSp': <tf.Tensor: shape=(8,), dtype=int64, numpy=array([1, 1, 0, 1, 0, 0, 0, 3], dtype=int64)>}
#
# tf.Tensor([1 1 0 1 1 1 1 0], shape=(8,), dtype=int64)

# %%
history = model.fit(ds, epochs=128)
# Out:
# Epoch 1/128
# 23/23 [==============================] - 0s 955us/step - loss: 0.4081 - accuracy: 0.7650
# Epoch 2/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4078 - accuracy: 0.7650
# Epoch 3/128
# 23/23 [==============================] - 0s 865us/step - loss: 0.4072 - accuracy: 0.7650
# Epoch 4/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4069 - accuracy: 0.7650
# Epoch 5/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4067 - accuracy: 0.7650
# Epoch 6/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4060 - accuracy: 0.7705
# Epoch 7/128
# 23/23 [==============================] - 0s 864us/step - loss: 0.4059 - accuracy: 0.7705
# Epoch 8/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.4054 - accuracy: 0.7705
# Epoch 9/128
# 23/23 [==============================] - 0s 864us/step - loss: 0.4051 - accuracy: 0.7705
# Epoch 10/128
# 23/23 [==============================] - 0s 865us/step - loss: 0.4047 - accuracy: 0.7760
# Epoch 11/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.4043 - accuracy: 0.7760
# Epoch 12/128
# 23/23 [==============================] - 0s 864us/step - loss: 0.4040 - accuracy: 0.7760
# Epoch 13/128
# 23/23 [==============================] - 0s 818us/step - loss: 0.4037 - accuracy: 0.7760
# Epoch 14/128
# 23/23 [==============================] - 0s 910us/step - loss: 0.4033 - accuracy: 0.7760
# Epoch 15/128
# 23/23 [==============================] - 0s 815us/step - loss: 0.4029 - accuracy: 0.7760
# Epoch 16/128
# 23/23 [==============================] - 0s 864us/step - loss: 0.4025 - accuracy: 0.7760
# Epoch 17/128
# 23/23 [==============================] - 0s 838us/step - loss: 0.4021 - accuracy: 0.7760
# Epoch 18/128
# 23/23 [==============================] - 0s 864us/step - loss: 0.4019 - accuracy: 0.7760
# Epoch 19/128
# 23/23 [==============================] - 0s 864us/step - loss: 0.4014 - accuracy: 0.7760
# Epoch 20/128
# 23/23 [==============================] - 0s 864us/step - loss: 0.4012 - accuracy: 0.7814
# Epoch 21/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.4008 - accuracy: 0.7814
# Epoch 22/128
# 23/23 [==============================] - 0s 955us/step - loss: 0.4004 - accuracy: 0.7814
# Epoch 23/128
# 23/23 [==============================] - 0s 864us/step - loss: 0.4001 - accuracy: 0.7814
# Epoch 24/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3997 - accuracy: 0.7814
# Epoch 25/128
# 23/23 [==============================] - 0s 864us/step - loss: 0.3995 - accuracy: 0.7814
# Epoch 26/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3991 - accuracy: 0.7814
# Epoch 27/128
# 23/23 [==============================] - 0s 865us/step - loss: 0.3987 - accuracy: 0.7814
# Epoch 28/128
# 23/23 [==============================] - 0s 818us/step - loss: 0.3985 - accuracy: 0.7814
# Epoch 29/128
# 23/23 [==============================] - 0s 864us/step - loss: 0.3980 - accuracy: 0.7814
# Epoch 30/128
# 23/23 [==============================] - 0s 829us/step - loss: 0.3978 - accuracy: 0.7814
# Epoch 31/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.3973 - accuracy: 0.7814
# Epoch 32/128
# 23/23 [==============================] - 0s 864us/step - loss: 0.
128
# 23/23 [==============================] - 0s 909us/step - loss: 0.3783 - accuracy: 0.7923
# Epoch 104/128
# 23/23 [==============================] - 0s 834us/step - loss: 0.3783 - accuracy: 0.7923
# Epoch 105/128
# 23/23 [==============================] - 0s 871us/step - loss: 0.3780 - accuracy: 0.7923
# Epoch 106/128
# 23/23 [==============================] - 0s 875us/step - loss: 0.3778 - accuracy: 0.7923
# Epoch 107/128
# 23/23 [==============================] - 0s 864us/step - loss: 0.3776 - accuracy: 0.7923
# Epoch 108/128
# 23/23 [==============================] - 0s 886us/step - loss: 0.3774 - accuracy: 0.7923
# Epoch 109/128
# 23/23 [==============================] - 0s 864us/step - loss: 0.3771 - accuracy: 0.7923
# Epoch 110/128
# 23/23 [==============================] - 0s 883us/step - loss: 0.3770 - accuracy: 0.7923
# Epoch 111/128
# 23/23 [==============================] - 0s 879us/step - loss: 0.3768 - accuracy: 0.7923
# Epoch 112/128
# 23/23 [==============================] - 0s 841us/step - loss: 0.3765 - accuracy: 0.7923
# Epoch 113/128
# 23/23 [==============================] - 0s 955us/step - loss: 0.3763 - accuracy: 0.7923
# Epoch 114/128
# 23/23 [==============================] - 0s 954us/step - loss: 0.3763 - accuracy: 0.7923
# Epoch 115/128
# 23/23 [==============================] - 0s 863us/step - loss: 0.3758 - accuracy: 0.7923
# Epoch 116/128
# 23/23 [==============================] - 0s 927us/step - loss: 0.3757 - accuracy: 0.7923
# Epoch 117/128
# 23/23 [==============================] - 0s 824us/step - loss: 0.3757 - accuracy: 0.7923
# Epoch 118/128
# 23/23 [==============================] - 0s 862us/step - loss: 0.3752 - accuracy: 0.7923
# Epoch 119/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.3752 - accuracy: 0.7923
# Epoch 120/128
# 23/23 [==============================] - 0s 844us/step - loss: 0.3749 - accuracy: 0.7923
# Epoch 121/128
# 23/23 [==============================] - 0s 905us/step - loss: 0.3747 - accuracy: 0.7923
# Epoch 122/128
# 23/23 [==============================] - 0s 881us/step - loss: 0.3745 - accuracy: 0.7923
# Epoch 123/128
# 23/23 [==============================] - 0s 818us/step - loss: 0.3745 - accuracy: 0.7923
# Epoch 124/128
# 23/23 [==============================] - 0s 818us/step - loss: 0.3741 - accuracy: 0.7923
# Epoch 125/128
# 23/23 [==============================] - 0s 910us/step - loss: 0.3740 - accuracy: 0.7923
# Epoch 126/128
# 23/23 [==============================] - 0s 875us/step - loss: 0.3736 - accuracy: 0.7923
# Epoch 127/128
# 23/23 [==============================] - 0s 874us/step - loss: 0.3737 - accuracy: 0.7923
# Epoch 128/128
# 23/23 [==============================] - 0s 845us/step - loss: 0.3734 - accuracy: 0.7923

# %%
test_data.shape
# Out:
# (418, 11)

# %%
test_data.fillna(0).shape
# Out:
# (418, 11)

# %%
test_data_features = test_data[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch']].replace(['female', 'male'], [0,1])

# %%
test_data_processed = test_data_features.to_numpy()

# %%
test_data_processed = np.array(test_data_processed)
test_data_processed = test_data_processed.reshape(-1,5,1)

# %%
test_data_processed = [list(temp) for temp in test_data_processed]

# %%
results = {
    'PassengerId':[],
    'Survived': []
}

# %%
for index, value in enumerate(test_data_processed):
    prediction = model.predict(value)
    prediction = int(np.around(prediction[0][0], 2))
    results['PassengerId'].append(test_data.iloc[index].PassengerId)
    results['Survived'].append(prediction)

# %%
results_df = pd.DataFrame(results)
results_df.to_csv('gender_submission.csv', index=False)
