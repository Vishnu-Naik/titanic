# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
train_data = pd.read_csv('./Data/train.csv').dropna()
test_data = pd.read_csv('./Data/test.csv').fillna(0)
train_data.head()
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 10           11         1       3
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 10      1   PP 9549  16.7000    G6        S
# 11      0    113783  26.5500  C103        S

# %%
input_features = train_data[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch']].replace(['female', 'male'], [0,1])
output_features = train_data['Survived']

# %%
binary_feature_names = ['Sex']
numeric_feature_names = ['Pclass', 'Age', 'SibSp', 'Parch']
numeric_feature = input_features[numeric_feature_names]

# %% [markdown]
# # Input vector

# %%
inputs = {}

for name, column in input_features.items():
    if name in binary_feature_names:
        dtype = tf.int64
    elif input_features[name].dtype == object:
        dtype = tf.string
    else:
        dtype = tf.float32

    inputs[name] = tf.keras.Input(
      shape=(), name=name, dtype=dtype)

inputs
# Out:
# {'Pclass': <KerasTensor: shape=(None,) dtype=float32 (created by layer 'Pclass')>,
#  'Sex': <KerasTensor: shape=(None,) dtype=int64 (created by layer 'Sex')>,
#  'Age': <KerasTensor: shape=(None,) dtype=float32 (created by layer 'Age')>,
#  'SibSp': <KerasTensor: shape=(None,) dtype=float32 (created by layer 'SibSp')>,
#  'Parch': <KerasTensor: shape=(None,) dtype=float32 (created by layer 'Parch')>}

# %% [markdown]
# # Preprocessing
# Unpack each row as one data sample using tf.stack.
# Convert the list of tensor into a tensor with rank one higher than each tensor

# %%
def stack_dict(inputs, fun=tf.stack):
    values = []
    for key in sorted(inputs.keys()):
      values.append(tf.cast(inputs[key], tf.float32))

    return fun(values, axis=-1)

# %%
preprocessed = []
for feature_name in binary_feature_names:
    temp = inputs[feature_name]
    temp = tf.expand_dims(temp, axis=1)
    temp_float = tf.cast(temp, tf.float32)
    preprocessed.append(temp_float)

preprocessed
# Out:
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'tf.cast')>]

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)
normalizer.adapt(stack_dict(dict(numeric_feature)))

# %%
numeric_inputs = {}
for name in numeric_feature_names:
  numeric_inputs[name]=inputs[name]

numeric_inputs = stack_dict(numeric_inputs)
numeric_normalized = normalizer(numeric_inputs)

preprocessed.append(numeric_normalized)

preprocessed
# Out:
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'tf.cast')>,
#  <KerasTensor: shape=(None, 4) dtype=float32 (created by layer 'normalization')>]

# %%
preprocesssed_result = tf.concat(preprocessed, axis=-1)
preprocesssed_result
# Out:
# <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'tf.concat')>

# %%
preprocessor = tf.keras.Model(inputs, preprocesssed_result)

# %%
tf.keras.utils.plot_model(preprocessor, rankdir="LR", show_shapes=True)

# %%
preprocessor(dict(input_features.iloc[:1]))
# Out:
# <tf.Tensor: shape=(1, 5), dtype=float32, numpy=
# array([[ 0.        ,  0.14906502, -0.6317298 , -0.37225628,  0.8336275 ]],
#       dtype=float32)>

# %% [markdown]
# # Build Model

# %%
body = tf.keras.Sequential([
  tf.keras.layers.Dense(10, activation='relu'),
  tf.keras.layers.Dense(10, activation='relu'),
  tf.keras.layers.Dense(1, activation='sigmoid')
])

# %%
inputs
# Out:
# {'Pclass': <KerasTensor: shape=(None,) dtype=float32 (created by layer 'Pclass')>,
#  'Sex': <KerasTensor: shape=(None,) dtype=int64 (created by layer 'Sex')>,
#  'Age': <KerasTensor: shape=(None,) dtype=float32 (created by layer 'Age')>,
#  'SibSp': <KerasTensor: shape=(None,) dtype=float32 (created by layer 'SibSp')>,
#  'Parch': <KerasTensor: shape=(None,) dtype=float32 (created by layer 'Parch')>}

# %%
x = preprocessor(inputs)
x
# Out:
# <KerasTensor: shape=(None, 5) dtype=float32 (created by layer 'model')>

# %%
result = body(x)
result
# Out:
# <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'sequential_1')>

# %%
model = tf.keras.Model(inputs, result)

model.compile(optimizer='adam',
                loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
                metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Age (InputLayer)               [(None,)]            0           []
#
#  Parch (InputLayer)             [(None,)]            0           []
#
#  Pclass (InputLayer)            [(None,)]            0           []
#
#  Sex (InputLayer)               [(None,)]            0           []
#
#  SibSp (InputLayer)             [(None,)]            0           []
#
#  model (Functional)             (None, 5)            9           ['Age[0][0]',
#                                                                   'Parch[0][0]',
#                                                                   'Pclass[0][0]',
#                                                                   'Sex[0][0]',
#                                                                   'SibSp[0][0]']
#
#  sequential_1 (Sequential)      (None, 1)            181         ['model[0][0]']
#
# ==================================================================================================
# Total params: 190
# Trainable params: 181
# Non-trainable params: 9
# __________________________________________________________________________________________________

# %%
keras.utils.plot_model(model, rankdir="LR", show_shapes=False)

# %%
ds = tf.data.Dataset.from_tensor_slices((
    dict(input_features),
    output_features
))
BATCH_SIZE=8
ds = ds.batch(BATCH_SIZE)

# %%
import pprint

for x, y in ds.take(1):
  pprint.pprint(x)
  print()
  print(y)
# Out:
# {'Age': <tf.Tensor: shape=(8,), dtype=float64, numpy=array([38., 35., 54.,  4., 58., 34., 28., 19.])>,
#  'Parch': <tf.Tensor: shape=(8,), dtype=int64, numpy=array([0, 0, 0, 1, 0, 0, 0, 2], dtype=int64)>,
#  'Pclass': <tf.Tensor: shape=(8,), dtype=int64, numpy=array([1, 1, 1, 3, 1, 2, 1, 1], dtype=int64)>,
#  'Sex': <tf.Tensor: shape=(8,), dtype=int64, numpy=array([0, 0, 1, 0, 0, 1, 1, 1], dtype=int64)>,
#  'SibSp': <tf.Tensor: shape=(8,), dtype=int64, numpy=array([1, 1, 0, 1, 0, 0, 0, 3], dtype=int64)>}
#
# tf.Tensor([1 1 0 1 1 1 1 0], shape=(8,), dtype=int64)

# %%
history = model.fit(ds, epochs=128)
# Out:
# Epoch 1/128
# d:\STUDY MATERIAL\Masters Study Material\WS2022\Thesis\CodeBase\thesis-env\lib\site-packages\keras\backend.py:5673: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Sigmoid activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6502 - accuracy: 0.6721
# Epoch 2/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6348 - accuracy: 0.6721
# Epoch 3/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6234 - accuracy: 0.6721
# Epoch 4/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.6134 - accuracy: 0.6721
# Epoch 5/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.6040 - accuracy: 0.6721
# Epoch 6/128
# 23/23 [==============================] - 0s 1000us/step - loss: 0.5954 - accuracy: 0.6721
# Epoch 7/128
# 23/23 [==============================] - 0s 937us/step - loss: 0.5870 - accuracy: 0.6721
# Epoch 8/128
# 23/23 [==============================] - 0s 944us/step - loss: 0.5788 - accuracy: 0.6721
# Epoch 9/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5708 - accuracy: 0.6721
# Epoch 10/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.5626 - accuracy: 0.6721
# Epoch 11/128
# 23/23 [==============================] - 0s 920us/step - loss: 0.5547 - accuracy: 0.6721
# Epoch 12/128
# 23/23 [==============================] - 0s 910us/step - loss: 0.5472 - accuracy: 0.6721
# Epoch 13/128
# 23/23 [==============================] - 0s 955us/step - loss: 0.5398 - accuracy: 0.6721
# Epoch 14/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.5326 - accuracy: 0.6667
# Epoch 15/128
# 23/23 [==============================] - 0s 954us/step - loss: 0.5253 - accuracy: 0.6667
# Epoch 16/128
# 23/23 [==============================] - 0s 939us/step - loss: 0.5178 - accuracy: 0.6667
# Epoch 17/128
# 23/23 [==============================] - 0s 867us/step - loss: 0.5108 - accuracy: 0.6667
# Epoch 18/128
# 23/23 [==============================] - 0s 927us/step - loss: 0.5041 - accuracy: 0.6776
# Epoch 19/128
# 23/23 [==============================] - 0s 955us/step - loss: 0.4976 - accuracy: 0.6831
# Epoch 20/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4911 - accuracy: 0.6885
# Epoch 21/128
# 23/23 [==============================] - 0s 921us/step - loss: 0.4849 - accuracy: 0.7158
# Epoch 22/128
# 23/23 [==============================] - 0s 872us/step - loss: 0.4790 - accuracy: 0.7268
# Epoch 23/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.4737 - accuracy: 0.7322
# Epoch 24/128
# 23/23 [==============================] - 0s 891us/step - loss: 0.4692 - accuracy: 0.7432
# Epoch 25/128
# 23/23 [==============================] - 0s 934us/step - loss: 0.4651 - accuracy: 0.7432
# Epoch 26/128
# 23/23 [==============================] - 0s 888us/step - loss: 0.4614 - accuracy: 0.7268
# Epoch 27/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.4580 - accuracy: 0.7213
# Epoch 28/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.4550 - accuracy: 0.7377
# Epoch 29/128
# 23/23 [==============================] - 0s 999us/step - loss: 0.4521 - accuracy: 0.7377
# Epoch 30/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.4493 - accuracy: 0.7486
# Epoch 31/128
# 23/23 [==============================] - 0s 992us/step - loss: 0.4470 - accuracy: 0.7486
# Epoch 32/128
# 23/23 [==============================] - 0s 896us/step - loss: 0.4448 - accuracy: 0.7541
# Epoch 33/128
# 23/23 [==============================] - 0s 878us/step - loss: 0.4428 - accuracy: 0.7541
# Epoch 34/128
# 23/23 [==============================] - 0s 854us/step - loss: 0.4409 - accuracy: 0.7541
# Epoch 35/128
# 23/23 [==============================] - 0s 942us/step - loss: 0.4392 - accuracy: 0.7432
# Epoch 36/128
# 23/23 [==============================] - 0s 880us/step - loss: 0.4377 - accuracy: 0.7486
# Epoch 37/128
# 23/23 [==============================] - 0s 875us/step - loss: 0.4360 - accuracy: 0.7541
# Epoch 38/128
# 23/23 [==============================] - 0s 925us/step - loss: 0.4348 - accuracy: 0.7596
# Epoch 39/128
# 23/23 [==============================] - 0s 962us/step - loss: 0.4334 - accuracy: 0.7650
# Epoch 40/128
# 23/23 [==============================] - 0s 930us/step - loss: 0.4321 - accuracy: 0.7650
# Epoch 41/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.4310 - accuracy: 0.7650
# Epoch 42/128
# 23/23 [==============================] - 0s 826us/step - loss: 0.4297 - accuracy: 0.7650
# Epoch 43/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4287 - accuracy: 0.7650
# Epoch 44/128
# 23/23 [==============================] - 0s 919us/step - loss: 0.4276 - accuracy: 0.7705
# Epoch 45/128
# 23/23 [==============================] - 0s 905us/step - loss: 0.4263 - accuracy: 0.7705
# Epoch 46/128
# 23/23 [==============================] - 0s 896us/step - loss: 0.4252 - accuracy: 0.7705
# Epoch 47/128
# 23/23 [==============================] - 0s 896us/step - loss: 0.4243 - accuracy: 0.7760
# Epoch 48/128
# 23/23 [==============================] - 0s 893us/step - loss: 0.4231 - accuracy: 0.7814
# Epoch 49/128
# 23/23 [==============================] - 0s 839us/step - loss: 0.4226 - accuracy: 0.7869
# Epoch 50/128
# 23/23 [==============================] - 0s 955us/step - loss: 0.4215 - accuracy: 0.7814
# Epoch 51/128
# 23/23 [==============================] - 0s 845us/step - loss: 0.4209 - accuracy: 0.7814
# Epoch 52/128
# 23/23 [==============================] - 0s 917us/step - loss: 0.4198 - accuracy: 0.7814
# Epoch 53/128
# 23/23 [==============================] - 0s 878us/step - loss: 0.4192 - accuracy: 0.7814
# Epoch 54/128
# 23/23 [==============================] - 0s 876us/step - loss: 0.4181 - accuracy: 0.7814
# Epoch 55/128
# 23/23 [==============================] - 0s 1000us/step - loss: 0.4175 - accuracy: 0.7814
# Epoch 56/128
# 23/23 [==============================] - 0s 922us/step - loss: 0.4167 - accuracy: 0.7814
# Epoch 57/128
# 23/23 [==============================] - 0s 829us/step - loss: 0.4159 - accuracy: 0.7814
# Epoch 58/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.4150 - accuracy: 0.7814
# Epoch 59/128
# 23/23 [==============================] - 0s 886us/step - loss: 0.4145 - accuracy: 0.7814
# Epoch 60/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.4134 - accuracy: 0.7814
# Epoch 61/128
# 23/23 [==============================] - 0s 864us/step - loss: 0.4132 - accuracy: 0.7814
# Epoch 62/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.4120 - accuracy: 0.7814
# Epoch 63/128
# 23/23 [==============================] - 0s 930us/step - loss: 0.4116 - accuracy: 0.7814
# Epoch 64/128
# 23/23 [==============================] - 0s 864us/step - loss: 0.4107 - accuracy: 0.7814
# Epoch 65/128
# 23/23 [==============================] - 0s 846us/step - loss: 0.4102 - accuracy: 0.7814
# Epoch 66/128
# 23/23 [==============================] - 0s 944us/step - loss: 0.4093 - accuracy: 0.7814
# Epoch 67/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.4085 - accuracy: 0.7760
# Epoch 68/128
# 23/23 [==============================] - 0s 920us/step - loss: 0.4081 - accuracy: 0.7760
# Epoch 69/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.4072 - accuracy: 0.7760
# Epoch 70/128
# 23/23 [==============================] - 0s 886us/step - loss: 0.4068 - accuracy: 0.7760
# Epoch 71/128
# 23/23 [==============================] - 0s 879us/step - loss: 0.4058 - accuracy: 0.7760
# Epoch 72/128
# 23/23 [==============================] - 0s 907us/step - loss: 0.4057 - accuracy: 0.7760
# Epoch 73/128
# 23/23 [==============================] - 0s 842us/step - loss: 0.4046 - accuracy: 0.7760
# Epoch 74/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.4043 - accuracy: 0.7760
# Epoch 75/128
# 23/23 [==============================] - 0s 922us/step - loss: 0.4036 - accuracy: 0.7760
# Epoch 76/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.4031 - accuracy: 0.7760
# Epoch 77/128
# 23/23 [==============================] - 0s 926us/step - loss: 0.4025 - accuracy: 0.7760
# Epoch 78/128
# 23/23 [==============================] - 0s 844us/step - loss: 0.4021 - accuracy: 0.7760
# Epoch 79/128
# 23/23 [==============================] - 0s 867us/step - loss: 0.4012 - accuracy: 0.7760
# Epoch 80/128
# 23/23 [==============================] - 0s 935us/step - loss: 0.4014 - accuracy: 0.7760
# Epoch 81/128
# 23/23 [==============================] - 0s 864us/step - loss: 0.4002 - accuracy: 0.7760
# Epoch 82/128
# 23/23 [==============================] - 0s 892us/step - loss: 0.4003 - accuracy: 0.7705
# Epoch 83/128
# 23/23 [==============================] - 0s 916us/step - loss: 0.3992 - accuracy: 0.7650
# Epoch 84/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3988 - accuracy: 0.7650
# Epoch 85/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.3984 - accuracy: 0.7650
# Epoch 86/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3976 - accuracy: 0.7650
# Epoch 87/128
# 23/23 [==============================] - 0s 955us/step - loss: 0.3975 - accuracy: 0.7650
# Epoch 88/128
# 23/23 [==============================] - 0s 885us/step - loss: 0.3965 - accuracy: 0.7650
# Epoch 89/128
# 23/23 [==============================] - 0s 928us/step - loss: 0.3965 - accuracy: 0.7650
# Epoch 90/128
# 23/23 [==============================] - 0s 964us/step - loss: 0.3954 - accuracy: 0.7650
# Epoch 91/128
# 23/23 [==============================] - 0s 960us/step - loss: 0.3953 - accuracy: 0.7650
# Epoch 92/128
# 23/23 [==============================] - 0s 940us/step - loss: 0.3944 - accuracy: 0.7650
# Epoch 93/128
# 23/23 [==============================] - 0s 864us/step - loss: 0.3945 - accuracy: 0.7650
# Epoch 94/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.3936 - accuracy: 0.7650
# Epoch 95/128
# 23/23 [==============================] - 0s 903us/step - loss: 0.3932 - accuracy: 0.7650
# Epoch 96/128
# 23/23 [==============================] - 0s 882us/step - loss: 0.3926 - accuracy: 0.7650
# Epoch 97/128
# 23/23 [==============================] - 0s 909us/step - loss: 0.3924 - accuracy: 0.7650
# Epoch 98/128
# 23/23 [==============================] - 0s 921us/step - loss: 0.3916 - accuracy: 0.7650
# Epoch 99/128
# 23/23 [==============================] - 0s 961us/step - loss: 0.3913 - accuracy: 0.7650
# Epoch 100/128
# 23/23 [==============================] - 0s 903us/step - loss: 0.3907 - accuracy: 0.7650
# Epoch 101/128
# 23/23 [==============================] - 0s 966us/step - loss: 0.3902 - accuracy: 0.7650
# Epoch 102/128
# 23/23 [==============================] - 0s 899us/step - loss: 0.3898 - accuracy: 0.7650
# Epoch 103/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3892 - accuracy: 0.7650
# Epoch 104/128
# 23/23 [==============================] - 0s 867us/step - loss: 0.3887 - accuracy: 0.7650
# Epoch 105/128
# 23/23 [==============================] - 0s 955us/step - loss: 0.3884 - accuracy: 0.7650
# Epoch 106/128
# 23/23 [==============================] - 0s 919us/step - loss: 0.3879 - accuracy: 0.7650
# Epoch 107/128
# 23/23 [==============================] - 0s 886us/step - loss: 0.3873 - accuracy: 0.7650
# Epoch 108/128
# 23/23 [==============================] - 0s 905us/step - loss: 0.3871 - accuracy: 0.7650
# Epoch 109/128
# 23/23 [==============================] - 0s 850us/step - loss: 0.3865 - accuracy: 0.7650
# Epoch 110/128
# 23/23 [==============================] - 0s 900us/step - loss: 0.3858 - accuracy: 0.7650
# Epoch 111/128
# 23/23 [==============================] - 0s 880us/step - loss: 0.3857 - accuracy: 0.7650
# Epoch 112/128
# 23/23 [==============================] - 0s 877us/step - loss: 0.3851 - accuracy: 0.7650
# Epoch 113/128
# 23/23 [==============================] - 0s 1000us/step - loss: 0.3849 - accuracy: 0.7650
# Epoch 114/128
# 23/23 [==============================] - 0s 983us/step - loss: 0.3841 - accuracy: 0.7650
# Epoch 115/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3840 - accuracy: 0.7650
# Epoch 116/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3833 - accuracy: 0.7650
# Epoch 117/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3829 - accuracy: 0.7705
# Epoch 118/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3826 - accuracy: 0.7705
# Epoch 119/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3820 - accuracy: 0.7705
# Epoch 120/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3819 - accuracy: 0.7705
# Epoch 121/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3813 - accuracy: 0.7705
# Epoch 122/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3808 - accuracy: 0.7705
# Epoch 123/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3801 - accuracy: 0.7705
# Epoch 124/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3801 - accuracy: 0.7760
# Epoch 125/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3798 - accuracy: 0.7760
# Epoch 126/128
# 23/23 [==============================] - 0s 990us/step - loss: 0.3789 - accuracy: 0.7760
# Epoch 127/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3792 - accuracy: 0.7760
# Epoch 128/128
# 23/23 [==============================] - 0s 1ms/step - loss: 0.3780 - accuracy: 0.7760

# %%
test_data.shape
# Out:
# (418, 11)

# %%
test_data.fillna(0).shape
# Out:
# (418, 11)

# %%
test_data_features = test_data[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch']].replace(['female', 'male'], [0,1])

# %%
temp = test_data_features.iloc[0]
temp = np.expand_dims(temp.to_numpy(), axis=1)

# %%
temp = [i for i in temp]

# %%
model.predict(temp)
# Out:
# 1/1 [==============================] - 0s 65ms/step
# array([[0.01075628]], dtype=float32)
